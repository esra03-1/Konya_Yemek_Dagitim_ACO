# %% [markdown]
# # BLG-307 YAPAY ZEKA SİSTEMLERİ - 2. PROJE ÖDEVİ
#
# **Senaryo 1:** Konya Yemek Dağıtım Optimizasyonu (ACO)
#
# * **Adınız:** Esra
# * **Soyadınız:** Gögebakan
# * **Okul Numaranız:** 2212721001
# * **GitHub Repo Bağlantısı:** https://github.com/esra03-1/Konya_Yemek_Dagitim_ACO

# %%
# Projenin çalıştırılması için gerekli komut
print("Bu proje Streamlit ile hazırlanmıştır.")
print("Çalıştırmak için terminalde şu komutu kullanınız: streamlit run main.py")

# Algoritma sınıfını test etmek için örnek (Opsiyonel)
from aco_algo import AntColonyOptimizer
import numpy as np

print("Kütüphaneler ve modüller başarıyla yüklendi.")
